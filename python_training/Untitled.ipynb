# %%
import numpy as np
import pandas as pd
from datetime import datetime
from dateutil import parser

# %%
from pandas_datareader import data

goog = data.DataReader('GOOG', start='2004', end='2016', data_source='stooq')
goog.head()
# Out:
#                Open     High      Low    Close   Volume
# Date
# 2019-05-06  1166.26  1190.85  1166.26  1189.39  1563943
# 2019-05-03  1173.65  1186.80  1169.00  1185.40  1980653
# 2019-05-02  1167.76  1174.19  1155.00  1162.61  1944817
# 2019-05-01  1188.05  1188.05  1167.18  1168.08  2642983
# 2019-04-30  1185.00  1192.81  1175.00  1188.48  6207027

# %%
goog = goog['Close']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()

# %%
goog.plot()

# %%
fig, ax = plt.subplots(2, sharex=True)
data = goog.iloc[:10]

data.resample('D').mean().plot(ax=ax[0], marker='o')

data.resample('D').mean().plot(ax=ax[1], style='-o')
data.resample('D').mean().plot(ax=ax[1], style='--o')
ax[1].legend(["back-fill", "forward-fill"]);
