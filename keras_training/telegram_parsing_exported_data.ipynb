# %%
import keras
import numpy as np
import random
import sys
from html.parser import HTMLParser

# %%
class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print("Encountered a start tag:", tag)

    def handle_endtag(self, tag):
        print("Encountered an end tag :", tag)

    def handle_data(self, data):
        print("Encountered some data  :", data)

# %%
path = 'msg/messages2.html'
file = open(path, encoding='utf8').read().lower()
parser = MyHTMLParser()
data = parser.feed(file)
data
# Out:
# Encountered some data  :
#
# Encountered a start tag: html
# Encountered some data  :
#
#
# Encountered a start tag: head
# Encountered some data  :
#
#
# Encountered a start tag: meta
# Encountered an end tag : meta
# Encountered some data  :
#
# Encountered a start tag: title
# Encountered some data  : exported data
# Encountered an end tag : title
# Encountered some data  :
#
# Encountered a start tag: meta
# Encountered an end tag : meta
# Encountered some data  :
#
#
# Encountered a start tag: link
# Encountered an end tag : link
# Encountered some data  :
#
#
# Encountered a start tag: script
# Encountered some data  :
#
#
# Encountered an end tag : script
# Encountered some data  :
#
#
# Encountered an end tag : head
# Encountered some data  :
#
#
# Encountered a start tag: body
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: a
# Encountered some data  :
# previous messages
#
# Encountered an end tag : a
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 12 april 2019
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 17:00
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# х
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# хромой бес
# Encountered a start tag: span
# Encountered some data  :  12.04.2019 16:41:56
# Encountered an end tag : span
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# у чым дасягнута прынцыповая згода?
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : — англійскую мову дзеці будуць вывучаць з 1 класа.
# Encountered a start tag: br
# Encountered some data  : — настаўнікам будуць даплочваць не за стаж, а за якасць адукацыі.
# Encountered a start tag: br
# Encountered some data  : — будзе распрацаваная іншая сістэма прафесійнай арыентацыі, бо існая не працуе, а захоўваецца для птушачкі.
# Encountered a start tag: br
# Encountered some data  : — набор на іт-спецыяльнасці будзе павялічаны ў 2 разы.
# Encountered a start tag: br
# Encountered some data  : — будзе перагледжана сістэма аплаты настаўнікаў так, каб у прафесію не ішлі горшыя.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 13 april 2019
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 13:29
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# photo
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# not included, change data exporting settings to download.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 650x433, 77.4 kb
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# как передаёт
# Encountered a start tag: a
# Encountered some data  : @radiosvaboda
# Encountered an end tag : a
# Encountered some data  : , в куропатах вновь снесли кресты. на этот раз металлические, которые стояли возле мкада.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : сделали это брсм и белая русь под видом "упорядочивания территории  к пасхе". насколько же совковую власть должны бесить обычные кресты на окраине минска, что их выкорчёвывают перед главным христианским праздником?
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 14:57
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# какую кличку агл заслуживает, после истории со сносом крестов в куропатах?
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# anonymous poll
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# - крестосносец
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# - крестоломец
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# - крестоборец
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# - богохульник
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# - что-то нецензурное
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 3413 votes
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 16:40
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# глава католиков беларуси
# Encountered a start tag: a
# Encountered some data  : тадеуш кондрусевич
# Encountered an end tag : a
# Encountered some data  : :
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered a start tag: em
# Encountered some data  : ещё раз обращаюсь к ответственным за снос крестов с призывом: остановите "крыжалом".
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered an end tag : em
# Encountered some data  : лукашенко создал уникальную ситуацию, в которой умудрился задеть чувства представителей всех конфессий, а также атеистов.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 14 april 2019
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 13:02
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# photo
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# not included, change data exporting settings to download.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 468x793, 58.0 kb
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# в бресте, несмотря на превентивные задержания лидеров, на протест против строительства завода акб вышли сотни людей.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : после призыва человека с мегафоном вернуть кресты в куропаты и остановить строительство акб, его попытались задержать сотрудники мвд в штатском. протестующие стали отбивать - и отбили. позже уже задерживали при поддержке отряда омона.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : в любом случае сегодня состоялся самый массовый марш, брест - красавцы и пример для подражания.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 20:57
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# photo
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# not included, change data exporting settings to download.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 785x423, 76.6 kb
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# именно так выглядит сегодня газон национального стадиона "динамо", который строил "лично лукашенко", и который стоил стране 200 миллионов долларов.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : напомним, что именно лукашенко отказал разрешить празднование дня воли и бнр101 на "динамо", мотивируя, что беларусы могут нанести ему вред.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 15 april 2019
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 10:32
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# photo
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# not included, change data exporting settings to download.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 1280x960, 229.3 kb
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# пока в минске сносят кресты, на лидчине ставят - в честь погибших там повстанцев 1863-ого года (восстание калиновского).
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : также министр культуры литвы в очередной раз согласился с тем, что на могиле калиновского (и других найденных повстанцев в вильне) надписи должны быть в том числе и на беларуском языке. перезахоронение наших героев ожидается осенью, многие беларусы уже готовятся к выезду в литву.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : напомним, что официальные беларуские власти очень долго игнорировали раскопки на гедиминовой горе, в результате которых были найдены останки константина калиновского и его соратников.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 19:10
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# photo
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# not included, change data exporting settings to download.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 956x537, 92.4 kb
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 10 человек вышли на молебен к администрации президента, ради защиты куропат.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : власть в ответ прислала автозаки, множество сотрудников мвд в штатском, а координировало "операцию защиты администрации" руководство гувд мингорисполкома.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : страна может спать спокойно.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 16 april 2019
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 10:59
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# photo
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# not included, change data exporting settings to download.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 600x390, 62.6 kb
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# многие с трагедией восприняли вчерашний пожар собора нотр-дам-де-пари. однако не все знают, что в беларуси 60 лет назад намеренно уничтожались храмы, которые пережили вторую мировую.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : 1. фара витова в гродно. берёт свое начало с 1389 года, не раз реконструировалась, пережила множество войн, осад и две мировых. взорван в бсср в 1961-ом году.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : 2. витебский иезуитский коллегиум. построен в 18-ом веке,служил местом образования и воспитания семинаристов. взорван коммунистами в 1956-ом году.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : 3. монастырь бернардинцев (витебск). памятник архитектуры 18-ого века, построен в стиле виленского барокко. в 1940-ом году власти его закрыли и сделали там антирелигиозный музей. спокойно пережив вторую мировую, монастырь уничтожили советские власти в 1961-ом году.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : 4. костёл святого франциска и иезуитский коллегиум (могилёв). памятник архитектуры 17-18-ого века, во времена российской империи переделан в церковь московского патриархата. уничтожен советской властью в 1950-ых.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : и это лишь ряд примеров из огромного списка.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 10:59
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# photo
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# not included, change data exporting settings to download.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 800x948, 255.0 kb
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 10:59
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# photo
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# not included, change data exporting settings to download.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 1280x854, 124.8 kb
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 10:59
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# photo
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# not included, change data exporting settings to download.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 632x827, 101.9 kb
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 15:50
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# п
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# протесты в мире
# Encountered a start tag: span
# Encountered some data  :  14.04.2019 19:55:43
# Encountered an end tag : span
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# не украиной единой. скоро выборы в беларуси, а значит начнут закручивать гайки. чтобы быть в курсе беспредела подписывайтесь на эти каналы:
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : -
# Encountered a start tag: a
# Encountered some data  : @nexta_tv
# Encountered an end tag : a
# Encountered a start tag: br
# Encountered some data  : -
# Encountered a start tag: a
# Encountered some data  : @belamova
# Encountered an end tag : a
# Encountered a start tag: br
# Encountered some data  : -
# Encountered a start tag: a
# Encountered some data  : @x1863
# Encountered an end tag : a
# Encountered a start tag: br
# Encountered some data  : -
# Encountered a start tag: a
# Encountered some data  : @studentyby
# Encountered an end tag : a
# Encountered a start tag: br
# Encountered some data  : -
# Encountered a start tag: a
# Encountered some data  : @nexta_lite
# Encountered an end tag : a
# Encountered a start tag: br
# Encountered some data  : -
# Encountered a start tag: a
# Encountered some data  : @belarus_lite
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 17 april 2019
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 12:01
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# пока беларуская власть занимается посадками жителей бреста за протесты и выдёргиванием крестов в куропатах, чем же занимается российский посол в беларуси бабич? правильно, формирует себе новую "боевую" команду.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : разогнав старые дипломатические кадры, бабич набрал себе в помощники следующих людей:
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered a start tag: strong
# Encountered some data  : алексей сухов
# Encountered an end tag : strong
# Encountered some data  : , советник-посланник. силовик, военный дипломат, выходец из главного управления генштаба вс рф (гру). у бабича в приволжье курировал внутреннюю политику регионов и работу силовиков.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered a start tag: strong
# Encountered some data  : андрей клинцевич
# Encountered an end tag : strong
# Encountered some data  : , первый секретарь посольства. служил в спецназе вдв, получил военное образование и перед приездом в беларусь курировал военно-патриотические клубы «молодой гвардии единой россии». весной 2014 года получил от путина почётную грамоту за захват крыма, регулярно ездил на донбасс, за что попал в базу данных «миротворец». украинские сми говорят, что его агентурный псевдоним в гру (внешняя разведка российской армии) - «гога».
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered a start tag: strong
# Encountered some data  : владимир андреев
# Encountered an end tag : strong
# Encountered some data  : , советник-посланник. до 2013 года работал в симферополе, где умудрился вызвать протесты местных жителей за критику фильма о сталинской депортации крымских татар.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered a start tag: strong
# Encountered some data  : кирилл колючкин
# Encountered an end tag : strong
# Encountered some data  : , военный атташе. до 2014 года работал в киеве в этой же должности, но был объявлен персоной нон грата. сбу задержала его прямо во время агентурной акции, и обнаружила при себе документы украинских силовых структур с грифами секретности.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered a start tag: strong
# Encountered some data  : константин гусев
# Encountered an end tag : strong
# Encountered some data  :  и
# Encountered a start tag: strong
# Encountered some data  : владимир маресев
# Encountered an end tag : strong
# Encountered some data  :  - советники посольства. украинские службы называют их штатными сотрудниками гру.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered a start tag: a
# Encountered some data  : прямо дрим-тим получился
# Encountered an end tag : a
# Encountered some data  : .
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 18 april 2019
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 16:01
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# макей:
# Encountered a start tag: em
# Encountered some data  : «куропаты должны быть благоустроены, но делать там все надо аккуратно, по-человечески.»
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered an end tag : em
# Encountered some data  : видимо глава мида беларуси начинает отмывать личный приказ лукашенко о сносе крестов. не удивимся, если вину за все в итоге свалят на главу лесхоза или остальных исполнителей.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 19 april 2019
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 12:08
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# лукашенко, сказал, что ему чиновники предлагают всех в интернете закрыть или создать какой-то отдельный интернет. ответил, что это чепуха, и надо вести ответную работу.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : мол, если кто-то на чиновников в сети сказал плохо, пускай они также противостоят публично в интернете.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : на практике же, силовики продолжают открывать уголовные дела как на крупные сми, так и на региональных блогеров и журналистов.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 12:18
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# лукашенко: президентские выборы должны состояться в 2020 году. парламентские - в этом.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 13:27
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# по поводу возможной переписи конституции и беларуси без лукашенко (по словам самого лукашенко) - пока что это лишь красивая реклама, расчитанная на не понять кого.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : вся беларуская система и вертикаль власти 25 лет выстраивалась лишь для того, чтобы набирать послушных исполнителей поручений от администрации президента. у нас нет никакой развитой самостоятельности и инициативы ни в парламенте, ни в судах, ни в министерствах. тот же "парламент" за 4 года работы самостоятельно разрабатывает лишь 1-2 закона.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : поэтому либо лукашенко будет держаться за власть дальше, либо кулуарно начнёт поиск преемника, который сможет гарантировать агл безопасность и покой.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : ну а если он действительно "так устал", то в ближайшие годы это должно быть видно по новой кадровой политике среди чиновенства.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 15:51
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# в 18.30 редакция начнёт стрим на youtube, посвящённый дебатам порошенко и зеленского на олимпийском стадионе в киеве. украинские выборы во многом повлияют на ситуацию в европе и мире.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : подписывайтесь на канал:
# Encountered a start tag: a
# Encountered some data  : youtube.com/channel/ucilaptsat8k52-fasy6vinw
# Encountered an end tag : a
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : также подписывайтесь на наш twitch для тех, кто любит игровые стримы:
# Encountered a start tag: a
# Encountered some data  : twitch.tv/18x63
# Encountered an end tag : a
# Encountered some data  :
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 21:46
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# хроника свежего и горячего конфлитка между минском и послом рф бабичем:
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : 1. утром, во время послания лукашенко, депутат канопацкая задала вопрос про стоимость аэс и электричества, которое там будет вырабатываться. также сослалась на бабича, что цена на аэс снизилась на 3 миллиарда.
# Encountered a start tag: br
# Encountered a start tag: br
# ...
#
#
# Encountered a start tag: div
# Encountered some data  :
# 905x1280, 181.5 kb
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# завтра (23 августа) в минске, в песочнице пройдёт бесплатный фестиваль от
# Encountered a start tag: a
# Encountered some data  : @symbalby
# Encountered an end tag : a
# Encountered some data  :  с участием годных беларуских групп и всяческими развлечениями.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : а в воскресенье (25 августа) в ракове пройдет крутой фестиваль беларуско-польско-еврейской культуры. будет много интерактива, а хедлайнером выступит volski.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 12:42
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# photo
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# not included, change data exporting settings to download.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 903x1280, 299.0 kb
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 23 august 2019
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 16:23
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# итак, что мы узнали за этот месяц насчёт будущих выборов?
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : 1. ермошина, говоря о возможности введения прозрачных урн, заявила: "
# Encountered a start tag: em
# Encountered some data  : это уже не модно
# Encountered an end tag : em
# Encountered some data  : ". более десяти лет беларуские власти не могли сделать дешёвых урн из орг.стекла, а теперь говорят, мол в мире новые тренды, надо стремиться к ним.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : 2. ермошина открыто и не стесняясь планирует будущий состав парламента так, как это приказано сверху: "
# Encountered a start tag: em
# Encountered some data  : по пожеланию главы государства около трети депутатов должно оставаться на второй срок
# Encountered an end tag : em
# Encountered some data  : ".
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : то есть каких депутатов лукашенко захочет, такие в палатке и окажутся, нет никакого намёка даже на иммитацию борьбы за мандат.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : 3. а вот что макей заявил о наблюдателях: "
# Encountered a start tag: em
# Encountered some data  : есть ряд желающих, которые не имеют никакого отношения к наблюдению за выборами и используют это в политических целях. какие-то там самосозданные структуры… мы будем делать всё в соответствии с белорусским законодательством, основываясь строго на его положениях и во взаимодействии с центральной избирательной комиссией, нашим парламентом.
# Encountered an end tag : em
# Encountered some data  : "
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : то есть наблюдателей от оппозиции, нго и просто осознанных граждан всеми силами не будут допускать до наблюдения.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : но скоро вы услышите от ряда политиков мантры о том, мол как это важно учавствовать в избирательном цирке, хотя они к нему даже и близко не готовы.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 22:05
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# video file
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# not included, change data exporting settings to download.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 00:20, 2.9 mb
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# в минске лампово прошёл фестиваль от
# Encountered a start tag: a
# Encountered some data  : @symbalby
# Encountered an end tag : a
# Encountered some data  : .
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 24 august 2019
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 19:20
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# photo
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# not included, change data exporting settings to download.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 1280x596, 123.2 kb
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# как передают ребята из
# Encountered a start tag: a
# Encountered some data  : @pozva
# Encountered an end tag : a
# Encountered some data  : , сейчас в минске, в парке дружбы народов проходит очередной пикет студентов против «закона об отсрочках». в ход пошли адаптации западных мемов, что довольно креативно.
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 25 august 2019
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# p
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# 13:30
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# palchys
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered a start tag: div
# Encountered some data  :
# уверен, что многие путаются с датами, которые связаны с независимостью беларуси в 20-ом веке. давайте кратко разберёмся:
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered a start tag: strong
# Encountered some data  : 25 марта 1918 - объявление независимости беларуской народной республики (бнр).
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered an end tag : strong
# Encountered some data  : первый серьёзный шаг беларусов на пути к обретению собственного государства, который был сделан после нескольких веков оккупации наших земель российской империей. в начале 90-ых получил дополнительное название "дзень волі".
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered a start tag: strong
# Encountered some data  : 27 июля 1990 - декларация о государственном суверенитете бсср.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered an end tag : strong
# Encountered some data  : под влиянием того, что россия и украина провозгласили независимость своих союзных республик, беларуские депутаты верховного совета бсср приняли аналогичный документ.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : однако "независимость" оставалась лишь на бумаге, не имея никакой реальной законодательной силы. также в верховном совете сидело много коммунистов, которые продолжали смотреть в сторону москвы и поддерживали идею жить в обновлённом ссср. для этого они оставили лазейку в декларации в виде пункта, который гласил следующее: "
# Encountered a start tag: em
# Encountered some data  : республика беларусь предлагает безотлагательно приступить к разработке договора о союзе суверенных социалистических государств.
# Encountered an end tag : em
# Encountered some data  : "
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : это повлекло конфликт и демарш депутатов от фракции бнф. позднее дата 27 июля с 1991 по 1996 отмечалась на государственном уровне как день незавимости, а затем лукашенко через референдум заменил её на 3 июля (день освобождения минска от нацистов).
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered a start tag: strong
# Encountered some data  : 25 августа 1991 - день, когда декларация независимости бсср получила конституционную силу и стала реальным законом.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered an end tag : strong
# Encountered some data  : в августе 1991-ого, в москве, произошёл путч гкчп, когда старые волки из кпсс пытались остановить развал ссср военной силой. путч провалился, после чего в беларуси со стороны гражданского общества стало нарастало требование придать декларации реальный конституционный статус.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : часть депутатов верховного совета (в основном коммунисты) сомневались, стоило ли голосовать за это. однако на улицы в поддержку независимости вышли люди по всей беларуси. только в минске перед домом правительства собрались десятки тысяч человек.
# Encountered a start tag: br
# Encountered a start tag: br
# Encountered some data  : в итоге декларация получила конституционную силу, и именно с 25 августа беларусь стала жить своей самостоятельной жизнью. таму ўсіх са святам!
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : div
# Encountered some data  :
#
#
# Encountered an end tag : body
# Encountered some data  :
#
#
# Encountered an end tag : html
# Encountered some data  :

# %%
maxlen = 60
step = 3
sentences = []
next_chars = []

# %%
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

# %%
print('Number of sequences:', len(sentences))
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
chars_indices = dict((char, chars.index(char)) for char in chars)
print('Vectirozation...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, chars_indices[char]] = 1
    y[i, chars_indices[next_chars[i]]] = 1
print('Success!')
# Out:
# Number of sequences: 200281
# Unique characters: 59
# Vectirozation...
# Success!

# %%
model = keras.models.Sequential()
model.add(keras.layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(keras.layers.Dense(len(chars), activation='softmax'))
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0823 06:52:55.442123  3296 deprecation_wrapper.py:119] From C:\Users\serge\Anaconda3\envs\KerasEnv\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0823 06:52:55.457121  3296 deprecation_wrapper.py:119] From C:\Users\serge\Anaconda3\envs\KerasEnv\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0823 06:52:55.459123  3296 deprecation_wrapper.py:119] From C:\Users\serge\Anaconda3\envs\KerasEnv\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0823 06:52:55.707122  3296 deprecation_wrapper.py:119] From C:\Users\serge\Anaconda3\envs\KerasEnv\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0823 06:52:55.713120  3296 deprecation_wrapper.py:119] From C:\Users\serge\Anaconda3\envs\KerasEnv\lib\site-packages\keras\backend\tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds)/ temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t,char in enumerate(generated_text):
                sampled[0, t, chars_indices[char]] = 1.
            
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text[1:]
            
            sys.stdout.write(next_char)
# Out:
# W0823 06:52:55.802131  3296 deprecation.py:323] From C:\Users\serge\Anaconda3\envs\KerasEnv\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# epoch 1
# W0823 06:52:56.230122  3296 deprecation_wrapper.py:119] From C:\Users\serge\Anaconda3\envs\KerasEnv\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/1
# 200281/200281 [==============================] - 142s 709us/step - loss: 1.9996
# --- Generating with seed: " as a physician: "how did such a
# malady attack that finest p"
# ------ temperature: 0.2
#  as a physician: "how did such a
# malady attack that finest power and the soul and sense and soun and the soul and all the soul and the sense of the sense of the soul and and and sounded the falther and the falther and and all the sense of the falther the falled the rest the sense in the soul and even in the perman the sense of the sense of the our the soul and such and his self-pain the soul and the falther the sense of the soul and the sense of the soul a------ temperature: 0.5
# he falther the sense of the soul and the sense of the soul and moral the rest under in in his contals of the rest and most of men and senses of the sole this must to depares of the huster and all the paint enting and
# the extance of the result besting of the fadit--the rest beconsidestion and power that the restion of the soul of the extent of his alst in the would gean and senses and late to the spient and and soul and socre intlateling he man even of the ------ temperature: 1.0
# pient and and soul and socre intlateling he man even of the strong, shich of to the fore is who farthereot eritiration man
#  painey of profulnent of the r iders all, oun men i maythery as mowed prepery curduses:
# ander or,
# yle souplong in who danypressed this hences, and ruld; one moding hand the an crapatent), their only truth a philosophy, such such to be wallt
# s in
# this not chosering he slees moder truse---a condingmus billences,
# nown viawed this plasuse------ temperature: 1.2
# der truse---a condingmus billences,
# nown viawed this plasuse it ried supowing-snepts
# arratht must fal the "munat, plach, founnerth bartaines are cs"" it. and furfterse, with fleacious anly his sfoul--with ainkes, words arieing unothannica
# tien
# sonnich ass, he
# cark fulwadre
# courntalificativer aiti, statey which seem buruaghy yeakhing pinagions doatene discifice une"--this selfouggl, his lofers;dleso glabseinis-boribe mone becient effect, bay vein extecistaepoch 2
# Epoch 1/1
# 200281/200281 [==============================] - 139s 695us/step - loss: 1.6378
# --- Generating with seed: "h blind
# prejudice, passion or fear, and surfeited ourselves "
# ------ temperature: 0.2
# h blind
# prejudice, passion or fear, and surfeited ourselves and the sense of the such and the soul the such of the sense of the world so in the soul and the such a such a songer of the sense of the such as the same and the such a such and whole something the such a science of the sense of the such and the such a such a sonce of the such a sense of the sense of the such and in the sense of the same to the sense of the such a such a sense of the sense of the------ temperature: 0.5
#  to the sense of the such a such a sense of the sense of the same
# to the belief in one and his sonether in the something sensity in a sure the instinct to the soul, such a human in the sense the sense of my sort of feeling to powerrity in the commons of the repowers and the the sumpless of the subjecten such mode of the our sensed the un his more one sension of the a such a sunding to powerful the place of the body modest when is see has to his such a for ------ temperature: 1.0
#  place of the body modest when is see has to his such a for yem to lomen, he constantered
# "sonce wa bad without
# if the such of thiselish pny,
# it,, than-aby these,
# -an the , this as refeernal of that the rraccesfal, semple--of piting must in the etlictly an
# thether "the chad as hemself about his these his predieues
# owing theie sangili humlap an a faith who really
# clast aramenturing," of mitude comise our all can be turn is
# philosophers, dreas" one, thinktuo------ temperature: 1.2
# se our all can be turn is
# philosophers, dreas" one, thinktuots,
# trich peas-. the by modern that regreeates!
# conschoss, and. nears and sacs, heart
# be secercts, i as who toust world, if ay r,--moreously," belituss (however and
# to selong, ho"plourd in this the aen moin polsoustid-fore. takes of badges in know. to it conberness--vibityme of thoughing which takes he ease the
# souchhicid a
# way righerousled tt
# such
# predu-ddon or
# cal it
# world immas effected agriideepoch 3
# Epoch 1/1
# 200281/200281 [==============================] - 137s 682us/step - loss: 1.5474
# --- Generating with seed: "hical formulas,--a ruling idea, which, together with german
# "
# ------ temperature: 0.2
# hical formulas,--a ruling idea, which, together with german
# the state of the state of the state of the strenger of the state of the state of the stronger the state of the stranger to be a state to the states of the state of the state of the state of the contrance of the state of the state of the stronger to be as the stronger and stronger the strong to the stronger of the stronger the state of the strave of the stronger the stronger of the state of the str------ temperature: 0.5
#  strave of the stronger the stronger of the state of the strenger of all his moral prover to be strengthing and emotions of the need to be a stronger the whole consideration of graduality to be whole forms of all the a formant who is its destrupthing to be state in the station of be way accestity of the outtering, in all be the stronger to the fast rest at the end was the stronger of the stronger things to be the stronger or profeation to the excestion to ------ temperature: 1.0
# things to be the stronger or profeation to the excestion to greatest pregaied; i lasts of ond chypop, as accest entays
# of crees
# of fearously flowtred expense--drited of the shoughtionman ratelitian taking, bictary supervoung, supersatners of the head be things, who have in the azk justice taken
# of, in things that the whole -sution.--for in the spiritialation marualic
# notation virtue detered, also solf a is the hreatness every causant lation is profauntatio------ temperature: 1.2
# solf a is the hreatness every causant lation is profauntation of its depless
# in
# itjudaly--this hever bettoix in restinct are not, he wish that it as : it wto
# never to freisuspond--neue.
# lr xuliytorous: in sentactment
# found colically nature nyulacesed, and incleantallinens: enowerd" with the be
# from samatniness), and courses,neration, of they aanthous" ed kepuad,
# all 2"batnest, it noge con tronsfr
# arp olow depth---it. on as music,ce," other, hang or compersepoch 4
# Epoch 1/1
# 200281/200281 [==============================] - 137s 683us/step - loss: 1.5017
# --- Generating with seed: "va
# suso, ed io in lei," and the latter when he interpreted i"
# ------ temperature: 0.2
# va
# suso, ed io in lei," and the latter when he interpreted in the such a desire the such a such the consequently and the such a such a delight the consequently in the such a delight and the consequently and the consequently and the consequently consequently and man in the same the consequently and the consequently and the in the such a such a depresent and the such a such a moral and in the such a such the present the such a such a man in the such a conseq------ temperature: 0.5
#  such the present the such a such a man in the such a consequence of means and the way have as the comparres of men
# and the can some deeptest and the consequently and active consequentive the sense of self-develosming a
# false--in the inspire and at i fear of the the somethese immeditions of man and in will also a modically, need of the sort of the desire to the comment of the naturics for an any some feeling and the be of the consequently in organidity of ------ temperature: 1.0
# ome feeling and the be of the consequently in organidity of the
# presurn and, the cromenter as hil owicks of the fee asy benest freedo orequadically them depine houg to find blins must be the present idultous extend and arwithiages of namely
# the same, one wise get far also to the idealke and theinces a biblress, injured speciese be strong tlau letsed and hege hardingless and have at one theural beone's
# mean in pleasure justice, and no tisted man he ahing in------ temperature: 1.2
# ne's
# mean in pleasure justice, and no tisted man he ahing in this an haumen
# againjuog, should should thereby accordint gerporn at as if should take. yin even deting, cos, reann
# itasmames the "fact, predical blued vademques and the seving -that is--! the kor, we to phecesk--as
# rowe dnution of -that grutablist, their fectorantide lich struggsly upwap accownals folen nine--it was especes ot we have
# coirarism apatise of hight, everyfoloping sfuingemy us a new epoch 5
# Epoch 1/1
# 200281/200281 [==============================] - 136s 679us/step - loss: 1.4706
# --- Generating with seed: " deduced cause and from cause is deduced the
# unconditioned. "
# ------ temperature: 0.2
#  deduced cause and from cause is deduced the
# unconditioned. the self-comple to the soul and the sense of the soul. the sense of the sense the soul, and all the such a point of the feeling and soul and the sense of the fact the sense of the soul, and the morals of means of the sense of the sense of a compared the such a soul and the hard and something the sense of the contrary and fact the soul and the soul, the sense of the sense the sense of the fine the ------ temperature: 0.5
#  the soul, the sense of the sense the sense of the fine the world and man, all--all the such a man appear and sort of self-revenal the against something the priest at the belief and avered and perhaps necessarily man be and formine, he stand the art, and the tasles and something he has been soul, and some compulsively and as he is a such the world of desire tone to luther to the contenty of freedom of the such a soul and are to the the sense of humanity of------ temperature: 1.0
# m of the such a soul and are to the the sense of humanity of moralis, inclusions. is a seeks feeling of "indeed of itmil laws
# have even in fully even solitude. one not neevost aconcerand of long than, wishes
# to be the possible for life and selved ixe allous as feeling to goetinantiven
# remorsive so hustow something most selcised then, whe the pomis is
# mens"valswions, homensismen. in humanity or i last on itself, and ammethess a responsinibyphy secret, so. t------ temperature: 1.2
# ast on itself, and ammethess a responsinibyphy secret, so. takes thems prospect likehting )y its his, tovesone. to monevers i detquiving also moray in theoogh,
# bad
# enlact
# venul. they also ungerman hanged throubts then they feel the genius, the appears ther! all-to
# little wystelit: for continued? and whoy through means ahy his compathed man; stet is german toops sentiment wish which andi!ancibee:--yould seem all-trush.
# jusive sort
# evil
# them does not strangepoch 6
# Epoch 1/1
# 200281/200281 [==============================] - 139s 692us/step - loss: 1.4503
# --- Generating with seed: "e
# original state founder, who subjugates the weaker. he has "
# ------ temperature: 0.2
# e
# original state founder, who subjugates the weaker. he has not and subject and and delight and strengther and soul and profounder and conscience of the sense of the sense of the profounder and and and spirit and subject and subject and superility of the desire to the properion of the same and objection of the profounder and delight and conscience of the sense of the properions and the spirit and self-antither and more and and the desire the strengther and------ temperature: 0.5
# self-antither and more and and the desire the strengther and the spirit and content of his man who has little really desire of an astention when the sense of the spiritual is profound the contemplance of the appearance of the word not itself, in the philosophy of the replated itself and derity of the again of a child and the conscious and
# constitute and
# opposite and curvoished and saurring and constitutes the german grant and among the science of the state------ temperature: 1.0
# stitutes the german grant and among the science of the state is necessit bast physish originment wastomenant modumation without do nature of florid ratis
# attempt, on varty, wish things"w forelotic an a
# most conseducted.
# and
# not privoilusional slichtening, leads ! "good" in our necessity and when the spironur-yws, move a subject carty an
# overbole. if one conbonogsionss comparo-lieth.ly also i do
# age here, however than allow mestabloo-iir hyposts"--ex my his------ temperature: 1.2
# e here, however than allow mestabloo-iir hyposts"--ex my his still
# gurmennal fratle, as will of his felling, arringing, upley with undistactled
# especie he seering unjused
# not, even like
# an upitive things and
# ynot innot viidea greathers on esty, highesty if hinsocyulgex
# withouts, a till and
# imourly the very fluith, that seoundly addient what desire what follition,
# it is inbidt
# crigit-igant, themselves, to whom ken badhed when as
# in
# to
# beenth of under
# to psyepoch 7
# Epoch 1/1
# 200281/200281 [==============================] - 140s 699us/step - loss: 1.4325
# --- Generating with seed: "les!" the skeptic, in effect, that delicate
# creature, is far"
# ------ temperature: 0.2
# les!" the skeptic, in effect, that delicate
# creature, is far and moral to the same to and man and contrary and contradict of the spiritual artism of the soul in the spirit of the personal artisted to the spirit to the moral and man and some moral and moral and sense of the moral contrary of the interpornation and morals of the science and superiority and present and subling to the sublimanive and the sublimance of the some moral and contrady and the princi------ temperature: 0.5
# the sublimance of the some moral and contrady and the principle, when they see as the pride, and superficiate the really
# propars in the faith of the conceal and also interpretation and content the sublimance on a bast of his man who is a misunderstand to a pride and distransation of superiority, the person and contrary and new populary the greater profound best discovered that
# the dispossible to sense--what the word to all all demands in the former to sens------ temperature: 1.0
# ense--what the word to all all demands in the former to sense--press within us deception for whom and ordern itself in tranive pertains of
# all successuhedraits all gracr-does evenrthat musicnk attained to overfzel; breakssad and absuld,achening,
# whith prediente romberted personative as illignted man, and not in quirery to imb german all establed,
# a higher or "it power communici.ieh would
# not far diftent art of rightation
# of such have been attaine that made------ temperature: 1.2
# iftent art of rightation
# of such have been attaine that made, other-dilach" and complecsapha gor"t,
# grest be rone simstacten things than subtis regard in many himself
# himself
# lichty degliment (porting
# physicar,
# the stater herlain, rank state ofctive"? itseld sutking he herd do not belieed normbust in durautions,
# this "can hence commorsplate meroly
# in virqual, menmuss himself, perhapst
# ; contre..y there
# in slinefurate
# fany chull.s keeperany , they
# modiubhdhepoch 8
# Epoch 1/1
# 200281/200281 [==============================] - 140s 700us/step - loss: 1.4201
# --- Generating with seed: "ted good. the very longing of the
# individual for self gratif"
# ------ temperature: 0.2
# ted good. the very longing of the
# individual for self gratiful self-conscience of the extent of the problemans of the same and developed the extrain and and consequence of the world the state of the entire and development of the prover the standity to the bad and demander the south of the probleman of the world and discovered the benendance of the state of the fair and degree the spirit of the provest of the state of the arting of the state of the extent o------ temperature: 0.5
# vest of the state of the arting of the state of the extent of the most the entire with the relation of the bady us to spirit unkerted and false and intellects and conscience, in the indifferent with the far the morality, the faith of the artises and also in the endisticians of disciploging to the amined the work and mecance of the word of the dangerous fallence that the domanical many and greather the conceited and the relation--it was the laws of the most------ temperature: 1.0
#  the conceited and the relation--it was the laws of the most hergreale conving that
# on the
# possible? is one like its orninatedness and
# give procourably done?--we are deducide proocsing the spirit ethen
# sublit of moral-imalment has
# a nature, of dislat
# one, and accordings and case of experiance, but unythes therebyed uninerines confling etho ambiful at is hidd,
# refurnce, rank"--those suscipatic of the pest unevodess--easievis and german religion for enbially------ temperature: 1.2
# he pest unevodess--easievis and german religion for enbially origabldance, thereby un,le
# creary and lord without their whole willing mefter, brought,," with
# the
# crotic hakistucal, ity have of on a
# soonosely dreadful) of
# mike" hech living--for
# sews what psychosocges seemned! las-connection of those formules of dolinity that it imple, for
# an enture ood"; poor keet. "good". god:--and bodsmend ala, from the aws, havciness its feel . about "metaphysical possiblepoch 9
# Epoch 1/1
# 200281/200281 [==============================] - 140s 701us/step - loss: 1.4094
# --- Generating with seed: "erhaps, in some future or other, serve as the
# axe that will "
# ------ temperature: 0.2
# erhaps, in some future or other, serve as the
# axe that will like the consideration of the conscience and sense of the more offerism of the sense of the spirit the partical the and consideration of the basis of the present and consideration of the moral the sense of the conscience of the consideration of the world to the belief in the consideration and conscience of the spirit the explanation of the consideration of the sense of the constantly and all the c------ temperature: 0.5
# e consideration of the sense of the constantly and all the complexers in the pation to manting the most perhaps the regarded is stated and
# deself--late the profoundly become soul of the conscience of the pripitimistic of thosices, the discoveres itself the sense of the consciouln, the will as a blener and man of the gregariciated to provest and distinct of the hereatesons of the proved and weaches and deceptioning and bundlers and opinion and refined for t------ temperature: 1.0
#  and deceptioning and bundlers and opinion and refined for the repariageroungist, by leche of the require mits
# hy deternable
# and moved med imselfacys and recognished keel.
#                                                                                                                                                    the threetom, perhaps educates. because to the efor. or i alfatedoust or fact, it all almost offeric spriets, why prevalements rigdatic
# matte------ temperature: 1.2
#  all almost offeric spriets, why prevalements rigdatic
# matter on the insimares of its are self-induct for desires.x woman.
#  rond only all, and
# remairistic ideed tonment. blear--things beence of a comprehants si. at
# catesty of griever promoding clastedvan in resples indeestor the
# old succeustes, desire bfole wommean thas the scharcs feeling.
#
#
# oe his aibtrum as a castomed ubperie can liest,
# thereforence, who
# chwret"-prevaranceful lightes; wey speftre for alepoch 10
# Epoch 1/1
# 200281/200281 [==============================] - 141s 704us/step - loss: 1.3977
# --- Generating with seed: "
# 209. as to how far the new warlike age on which we european"
# ------ temperature: 0.2
#
# 209. as to how far the new warlike age on which we european the fact the good of the supposed the fact the belief of the present and should to the the concerned the work of the problem of the pure and still and same and same of the work of the man of the standards of the personality and still and sacrifice of the standards of the good and the perhaps and concerned the work of the problem and such a commans of the contrary the personality of the good and s------ temperature: 0.5
#  a commans of the contrary the personality of the good and such his man the age of the prost of the fact the general
# still for the the the lage
# in the gradually great divines as the understood" must and suffers and every sentiments to the pervood of the stand and discontrary and such a personality and conscious commens of the spirit and consequence of many the distinction of the the have to the perspecticish, the personality and many in the moral problem a------ temperature: 1.0
# rspecticish, the personality and many in the moral problem and sympathy, (or oughordiated, in most anomedees if absulkences.
# into his yan dogtla, long of fully, good,"--or must after =may healty.
#
#
#   uration, took of rofted the foute. how rest we mrongent, not have the "wask all thas the percelver, in its vance, as because their obgrodulity
# in shoulst to a ghe the affectless. the trittes" when the old yourhily a more lough morality is the applets alwokerly------ temperature: 1.2
#  old yourhily a more lough morality is the applets alwokerly and read uslick, such stand foow; to what,
# how the
# rest becons its religion;--acders is
#  even whrekedbeebverer
# shubelity: and mooth, as
# this cluse fraturistic has livss prostocting in re schopens agest should himself from a
# gsdessr, with tonsh,
# no hinthing aboye man naturalism is goodments
# faith fhenogisuadk that honourous, perhaps the men what avoud live -they perhaps for him anstinate to etry aepoch 11
# Epoch 1/1
# 200281/200281 [==============================] - 140s 698us/step - loss: 1.3929
# --- Generating with seed: "
# world," namely through errors of the reason, through which "
# ------ temperature: 0.2
#
# world," namely through errors of the reason, through which has a consequence of the sense of the spirits of the person of the most suspect and the sunders of the superily in the consequence of the propouted and such a person of the person of the command--who has also in the senses and the senses in the development of the process of the fact of the propouted in the strenges of the strenges and in the sunder and something of the sunder of the fact the strug------ temperature: 0.5
# the sunder and something of the sunder of the fact the strugmment, and something and seef. a spirit, and man is a soul in the spiritmment of the has been those of the freedom of one like a distinction and the thished in the powerful of philosophy and great disposition of the art itself, and and understation of the late in the same and the philosophy one all as the dispossible and and spiritmment of his delicate the beautifues in the fair's most intellectua------ temperature: 1.0
# f his delicate the beautifues in the fair's most intellectually seroisile of the social lut everychion."
# indeedous the humns, disapperates of poit
# as the buck that comical maluctives fingle and fruence," of the through become who called moral
# great popular his econoloa, and the understrud they constantly, not i been, they are midd, finder unpredimage--who relight that of ? kint
# who has been also, and and
# thought terribl to a peryor. it in ksonhing embidiou------ temperature: 1.2
# and and
# thought terribl to a peryor. it in ksonhing embidious
# are, i (and (and theor.-inderd promptly
# alposit "a., sow than
# he a callation--of decigces eny anonoses when theyse he is now araworious called
# ieboule, have
# compare nronne. what--under of yle of hell.". for
# to madadl. plyameshow
# a perhaps, and satisfagime impluseds. their socials, its harn, happinect oe it is a us-imagreshable
# body hemplitate whan w they
# "shortouty have
# still with investines,
# mepoch 12
# Epoch 1/1
# 200281/200281 [==============================] - 140s 699us/step - loss: 1.3858
# --- Generating with seed: "there thereby results, and has always resulted in
# the long r"
# ------ temperature: 0.2
# there thereby results, and has always resulted in
# the long religion of the master of the strength, the religion of the probably and spiritual and the spirit of the problem of the sense to the sentiment of the contrary and such an action of the problem of the strength of the most probably be a stricted the contrary and the sense to the problem of the faith, the against the more and stand to the sense and spiritual and self-probably the strength, the sense a------ temperature: 0.5
# se and spiritual and self-probably the strength, the sense as the against the instincts may be fact the word in the contrary to be are many of the sense to the future, and the lighten rustimately provical probour of the tradition of the most general, as the delight of the former into the fact the whole likeled finally, the principal than is the contradiction of the assument and contrary to themselves. the traged and our well as when the truth actor the peo------ temperature: 1.0
# ves. the traged and our well as when the truth actor the people.
#
# 11ile
# C:\Users\serge\Anaconda3\envs\KerasEnv\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# ctings
# its
# opiepant appealse the other pulture it
# oning
# against it to dece. name nalomy happiness fee as music
# compunion, and pernicive truth of o "the conglege, arre
# promises the about the dangerous
# quire, more our authh ta that is tuped as despises to stil timeded has
# complexent that
# it have bad such an aarians dingerd the end,
# divine it have dece. begaol,
# sempious .i
# thether we lich ------ temperature: 1.2
# d,
# divine it have dece. begaol,
# sempious .i
# thether we lich thereofotrency .iity
# which a worre: the general feamath). what delicately, bad the psychoodly, in order tempitating mofted
# in the gramels, its action sounds an
# essent, smagacterity
# of
# equalles slaves; and self out arla; its lowp. as
# it be contaicouran characted the an the dnew brought! quiosime, and humanity when finally truth in therefore, the him. has hitherto beens-inknieg things. why wishes flepoch 13
# Epoch 1/1
# 200281/200281 [==============================] - 139s 693us/step - loss: 1.3801
# --- Generating with seed: "he other is. for instance, in a person
# created and destined "
# ------ temperature: 0.2
# he other is. for instance, in a person
# created and destined to be the propose of the best see if the same to the best and the spirit of the contrary of the command, and the same to the sense of the subliment of the superficial the sense of the sense of the superficious and subliment of the sense, and the standard to the sense of the common who come the same of the standard of the sense of the same are the subliment of the sense of the same to the same to t------ temperature: 0.5
#  are the subliment of the sense of the same to the same to the bergender and self-except of the primate the sacrificed to be something is propoulan
# to sublication of the feeling in the old said in all the most transcends of the dogma. when i say, and the last superficious be man, and say it is never an and history, in the broughthient, as as it do need in the prevails, to him even the sense and confessive of his higher the propontification of the best
# arti------ temperature: 1.0
# nfessive of his higher the propontification of the best
# artimates, but has
# , wherefseres ; creame even of onee discreption of strangupan gold, loke the burd norbar france wo"se which be me-great france, and religions. their selfmstiges, come, man there is now languich: compure are the world errory much can to the same sugvimgurance and meankners and cause of unifiusboric that when man.
# recognibgousfquass the fegrment with this demotes,
# evil.y
# whom their to------ temperature: 1.2
# sfquass the fegrment with this demotes,
# evil.y
# whom their too writurac
# pridatictaving them being mankind of his almost which in bad throwalnesm always alif,h-garvarrustives--yut who is growly. i him courseged belief
# of longeriations your smeadial, deouncefulhimy and
# fuct, by one's truth
# being even apavent ploor.
#
#
# i
#
# eghiston can
# well meansor time trarson of lived, iy who upon o undercisive ourselves bad again;
# in sin and igsuren oppossime of mobedientoriepoch 14
# Epoch 1/1
# 200281/200281 [==============================] - 139s 694us/step - loss: 1.3741
# --- Generating with seed: "t is manifest that the world is neither
# good nor bad, (to sa"
# ------ temperature: 0.2
# t is manifest that the world is neither
# good nor bad, (to say, the sense of the sense of the sense of the same are the same to the sense of the sense, the stronger and moral contrary, and the sense of the sense of the soul of the sense of the sense of the states of the struggle the self-persumphation of the sense of the sense of the sense of the sense of the same to the soul and the sense of the same sublity of the soul of the sense of the commons of the s------ temperature: 0.5
# ame sublity of the soul of the sense of the commons of the sense of the engling to the the things, and the fear of the trong the sublized religion and spirit who fartly and had to only the persuated and are the soul he and in the general moral present and the truth of the transities of command, and but the moral really as the subjection of the self-force and the feeling the sense, the all the same to the decide and suffered of the self-european deceivery o------ temperature: 1.0
#  to the decide and suffered of the self-european deceivery of mirdorisant and world toere are truth's feels these the yea hatime scriwn sweak; the sign itself.
#
# a4d understand, a spirit, his doep the onty saprion
# and a
# really
# conters origin--from the losing of its whole learlary is. "to him, he symptsm. thereofbetyme made only been to be
# destrustiness of this disuals, soul in the contrartion
# and palt hand-partion of individual and avertelius to feels holve------ temperature: 1.2
# alt hand-partion of individual and avertelius to feels holve, one hastores the emotion in offered untelld vigmant that
# rugtest and dodkents. furni. virtuy, that permad and simely of its various here,
# them
# and elem
# est there. protic all truth. they be
# the hudden rights the
# egoior aritar, symptoms, pailfjue,
# still,  the pethagicioral whether in a lifes
# exeventness, from agnive to these reldigres
# hilhuemean for their denociof.
#
#
# 131
#  i (di he the real
# paroriaepoch 15
# Epoch 1/1
# 200281/200281 [==============================] - 140s 700us/step - loss: 1.3693
# --- Generating with seed: "
# occasions pain, therefore it is false. the free spirit, who"
# ------ temperature: 0.2
#
# occasions pain, therefore it is false. the free spirit, who have to be a more and the most the standard of the world of the stronger of the conserve and philosopher and spirit of the greatest the spirit of the spirit and supernation of the preway and the world and perhaps the spirit of the fact the spirit of the spirit of the most and the strength and also the spirit is the consealence of the period of the consideration of the consideration of the prewall------ temperature: 0.5
# iod of the consideration of the consideration of the prewally conditions of him to be accept disposition of the old science, to the distincties, the bom and also and way and accumulate feel of the delivation of the defict of life in the bast of the reprource the philosophic moral themselves it as it is the problem the things of this deliving as the consideration of the science the prequaince, and all the very discled himself and that an inspire and conscie------ temperature: 1.0
# all the very discled himself and that an inspire and conscience of the delivation of
# the
# corres brough or come such inuline of proones of the baster life,
# of stopen. "is morals the result crasis then and recognized inclaty of the same englails and would should perhaps no renamencen and enjoying general its roffer, such a sented exmouting with stand, one trike
# and reconds bevents was self says the most mode and contemporally them it is profound formulations------ temperature: 1.2
# most mode and contemporally them it is profound formulations idences" to exercises tmank done womaning a britvine to what insplant
# of apprexxerenay, the remases of one has always fyought," does itaist.
# regal.man three forexie-s,ulonga, mhranssually,--it with gree distrumnius and glant move of all thin, i man of man--and bad stave of eunyties she masters is believe single; tendutious, we usical nations of the result it happiness profucheier
# natule, living--epoch 16
# Epoch 1/1
# 200281/200281 [==============================] - 139s 694us/step - loss: 1.3664
# --- Generating with seed: " of time and is not of
# yesterday--namely, according to the p"
# ------ temperature: 0.2
#  of time and is not of
# yesterday--namely, according to the profount to be a propourable and interpretation of the sentiment of the sense of the sentiment of the sense of the sentiment of the sentiment of the sense of the sentiment of the sentiment, the sense of the morality of the sense of the sense of the state of the sentian some sentiment of the spirit of the sentiment of the sense of the soul in the discoverent and the soul is the sentiments of the sen------ temperature: 0.5
# in the discoverent and the soul is the sentiments of the sentians of the most long and the word and some proved and case of their sought, and all the conbection of the reconce and spirits of the bast of such sentiments of moral free spirit and and a sense of the sentiment which is also a type of the world the enough by all sense of the same that the sentiment, and perhaps, and the soul is all the soul which is not the bast and same to be soul? the sentence------ temperature: 1.0
# soul which is not the bast and same to be soul? the sentence is at anw as
# inclosched spirit
# love wion pride for
# his any democrect inclosmfo
# call goe the spirit, that the more fare not too "by own errorm--alllged, althood-leads his
# averageed--and the nempance in centinations
# suc? that may reverection of certain means and the lifeiation to one. thus end vialied, and la
# powors. and the useflion fimulity of evil", and guetur. as seldom things"--the
# taste of hi------ temperature: 1.2
# ity of evil", and guetur. as seldom things"--the
# taste of history of
# these ainch. the
# thingsnes: why
# perblumed about more "buttlably wombule: they a origing that generationation; throws ivget for himself himself"-hupan: to be fremast dilactenarnch, budd"-christiousnessm derist knows! , our similar decept.=--in every
# herige reselves; internally guise
# nature.
#
# 1o†--stanghises
# (loxeyach-happans artolements for heavent, and a like of could after appoir" of
# to epoch 17
# Epoch 1/1
# 200281/200281 [==============================] - 139s 696us/step - loss: 1.3611
# --- Generating with seed: "ce which wished to test itself by such a subjugation; the
# st"
# ------ temperature: 0.2
# ce which wished to test itself by such a subjugation; the
# strength of the sense of the same sound the sense of the soul of the same to the same and souls and any one the sense of the spirit of the spirit of the sense of the strength of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the constantly and the most disposition of the sense of the soul of the strength of the spirit and the sense of the strength of the s------ temperature: 0.5
# trength of the spirit and the sense of the strength of the spirit impreservation as i destroys--the sure and weak--in the stranges and share of the extent of the basis of the tragery and deception of the contents of the same privile to intermating of all the highest man we constantly something, and their extraish, that alone the essential, and should not the factity; and have been a something of the happened that is the controlish which subters the thing t------ temperature: 1.0
# he happened that is the controlish which subters the thing to the science
# ever
# it were the pre"mest every thing
# inless youthvaniage" of al covents that obviouse.
#
#
# 1a1 of ancient pitcosune, enfortion, which have to; constantity. that has not the offor" yet to the most
# bad and horround, apshain in a geter, from person the religion which is done conscending,, have deal--what funds athers of which the willings of spirit reasonal man-to
# under every general sa ------ temperature: 1.2
# e willings of spirit reasonal man-to
# under every general sa fivious consigreslod
# contriouous
# unphilosopheral, if
# their
# serroto-hate, a being, the result of those slave-highent. the
# que of but
# togethers,
# as most tribegow, not, of mood and
# feciflingay may have doathd, when its coy truch our latily mast! if it wailings the
# godse )judetted? "howet if so impositing-nepeoning gulles at its that fasting as as
# bad in
# love oness to only regards jquans sow to youthbepoch 18
# Epoch 1/1
# 200281/200281 [==============================] - 139s 695us/step - loss: 1.3581
# --- Generating with seed: "morse of conscience: how
# it upbraids itself, how impatiently"
# ------ temperature: 0.2
# morse of conscience: how
# it upbraids itself, how impatiently the world of the superity of the comprehended for the sense of the consequence of the fact and the basis of the sentiment of the spirit of the superiority to the stronger and all the things of the present spirit of the simpliwn of the sense of the artistic and spirit of the same healthing in the freedoman superficial and superupon the same are the sense of the part of the superiority to the conse------ temperature: 0.5
# me are the sense of the part of the superiority to the consequence to be a "discovere experienced the profound the instincts and individual complainand the fearful so of the proprisus and closely the moral conditions and the world that every his really in our fundamental allow it is the profound that is not east and the soul of an end individuals who has been the word of the problem is the thoroughly the great developed to the compelare and spiritual, even------ temperature: 1.0
# hly the great developed to the compelare and spiritual, even sicknds it ask
# own the fasoorite, and nothoous hard betray is too unility of the beta only state, and,
# how
# wablection of the heart: artiwn, man" all purpose what even who is nexined it must be weakness--for not are bood innecence sensitions, which survel loves make as the perpentions, who are name of en tucts itself.
# i selsed morald tobody.
#
# 111. drew asnable of corristand's far for francement! w------ temperature: 1.2
# dy.
#
# 111. drew asnable of corristand's far for francement! who sufficience of thought learn to lrustal inspiled hen way for all rule." "ou up fere and regard in sganed who pull, what ha powerks, in
# artiage--apalted conduce: "the very opporition
# peynte to be
# sumul he german xhable is it decotates ? " his own general mosi nothions, can becals. to seemain pecuristry strengthe
# fashers, but whenever has ske most tup  romatisuid. its feeling is. thus connectellyepoch 19
# Epoch 1/1
# 200281/200281 [==============================] - 139s 694us/step - loss: 1.3545
# --- Generating with seed: " unity, posit the question--truly a very living question--: "
# ------ temperature: 0.2
#  unity, posit the question--truly a very living question--: whould has always and intellectual the world and strength and the world in the subject the soul the good and hardly the same decention of the strongest and preserve the sentiment of the superiority of the preserve the sense of the south of the preserve to the strongest and the problem the soul and subject and the soul and the problem of the superiority of the complete
# spirit and the and the soul a------ temperature: 0.5
# he superiority of the complete
# spirit and the and the soul as the better and suffer--or to the soul is the persons of the south, and restonded to the spurces of the suffers to antithess of the faith of life, the subject powerful so the
# last decised the
# individuals the strength in the concealed to and in the transcriquence of life and conselver of the subject that was to self influence of a philosophers of the came aristocratic intellect the emotions. but i------ temperature: 1.0
# phers of the came aristocratic intellect the emotions. but it is
# to the also a subject spirit of spont, is in recant of the very aris is thes is its sometet europetce
# subonis of recenting the get to good, erotoss nowaday life and spirit as ecolore; to then. one is respect of objective
# and
# expression, to us-cases in this "gall
# from to ateet for his sentaile, and the sentic as a
# store a trutes, that an a
# bany a german: anvatkee. the travelers.--the reasonees------ temperature: 1.2
#  an a
# bany a german: anvatkee. the travelers.--the reasonees,
# as his artistful hatles, too, to aughs. all (that and
# rendo'mulds (and psclukouss, would pasty humeman simnigity of truthing rate of glote
# nals to overinging
# standbmensiate spoil and indivisful classe of tyrance, to o necessarie best life mankind on which the bible.
#
# indiin satistys of pley only
# that,
# the effect in alies.
#
#
#
# i
# let only have religion with re, above at present assume for not to poepoch 20
# Epoch 1/1
# 200281/200281 [==============================] - 139s 696us/step - loss: 1.3505
# --- Generating with seed: "ruth," these coming philosophers? very
# probably, for all phi"
# ------ temperature: 0.2
# ruth," these coming philosophers? very
# probably, for all philosophical still a present and superficiation of the world and superities the stronger and all the sense of the sense of the sentious and seeks a strength of the sentious sense of the stronger to the sense of the sense of the sential of the sense of the sense of the contrary and still the sense of the sense of the present contrary the contrary in the contrary the stronger to another the stands of ------ temperature: 0.5
# trary in the contrary the stronger to another the stands of the states he even the sight and love the sentius and present love of himself is as its religious a thing the fair in its action of the specially in the last for the contrary in the follene and make of so experience, contrary and all the moral, the finds a society in the religious good endure in the intellectual in the experience, the germany which is a sound and any assert and a propoulable as it------ temperature: 1.0
# many which is a sound and any assert and a propoulable as it deours become mirne", or manabit things hadet, reble to be a still present so it recating so of him; the indivitual mind". however. sobe as
# the
# knows a
# believe things
# were instance,aal? for "love at institutly to
# conscience to its repeated hmpermanceabirage, above all,
# one with things things--the expeanant weaknable, it is to ugrating to feelone in eviness have sutrests,
# it "jest by the godness. ------ temperature: 1.2
#  feelone in eviness have sutrests,
# it "jest by the godness. the
# hyphhicalistic chatw denage
# have
# an aid that they reading vigely time itself, our
# refatey whether
# a sews how moraleiont, the seemomes hamsel"-uinted. crokes
# reking asially view pitid in every bloodebon knowledge, we have divired, with all indeed if we
# could e"ger; too sunsified overthvice,--there please would advining dogalen must be you, namely friendl enteratious atomin moreover. detrous worepoch 21
# Epoch 1/1
# 200281/200281 [==============================] - 139s 694us/step - loss: 1.3481
# --- Generating with seed: "n general held a valid
# justification, then nearly every mani"
# ------ temperature: 0.2
# n general held a valid
# justification, then nearly every manifest to the the morality of the fact the art of the soul is the morality of the soul is in the soul is the faculty of the soul is the morality of the soul is not so in the sense of the personal to the same to the soul is the soul is a soul is the states the soul is the soul is a soul is in the soul is a sort of the soul and consisted to the problem of the soul is a soul is a soul is the morality o------ temperature: 0.5
# he problem of the soul is a soul is a soul is the morality of the soul as the best for pleasure and one's interpreted the gods to contrary and know which the most some and and by the souls of the morality, as who consists in its long--the proounded were the other of the speciously or at all some in the sense of the precieent in the suffered and part of the expaller our suffering who have and in the free to some new the personal strongest conceival with the------ temperature: 1.0
# e free to some new the personal strongest conceival with the name
# human over "to be in ponths only innocent and not  olitines have, who, the offer something (own suyer find in this thought of an eyes, with the submbtrait, much "ifratism, him also
# among else
# sac"ificates. who,ably is
# a fast fundamentalismicly they from, and our probleend, the soul and listly, the end as at the most contrary
# logic are all inflictent stor,
# the light paterntims wants, or at th------ temperature: 1.2
# re all inflictent stor,
# the light paterntims wants, or at the profound conditional
# seen
# through the wacks who
# beginnicbefency the south, and old memere "corvqailantly apying it
# religious, in an religious fastios, full to-dow uak eurous. tzusive to its punine"
# weak new itself to
# su-reassone to becuth,
# thee to be iokicterm ypeases, how pertriately slaveres", ;fo. comcult, and sate welling the bet itself on nature's
# practla punn ssquicealy who is be a love whepoch 22
# Epoch 1/1
# 200281/200281 [==============================] - 139s 694us/step - loss: 1.3452
# --- Generating with seed: "nes
#
#      the greatest sin of man
#      is the sin of being b"
# ------ temperature: 0.2
# nes
#
#      the greatest sin of man
#      is the sin of being be a state of the spirit, and some of the standards of the standards of the spirit and soul is the spirit of the significance of the problem of the belong" to the spirit of the first the consideration of the still the spirit, and and and consist and the moral probleg of the spirit, and some and some problem which is the standards of the problem for the morality and soul is always and the state of t------ temperature: 0.5
# oblem for the morality and soul is always and the state of the internal of the old of all this individual the order to deception of the things of the apposing of the fagitest attempt the noble to as with a "from which is not the spirit. the soul has seek an instincts as the developed
# to consider and species.
#
#
#
# hate
# to the power.
#
#
#
# ho
# uice to be a may been the destrument of his religious problem with which the complexance of the standard which still and s------ temperature: 1.0
# with which the complexance of the standard which still and sound its aomonases ah formerly pours has such not kinged that noble become wait, provenged in law more in this will with this violnt of provestys,
# to which is althte embilly always being is happen;
# more democratic, when atterment, goodness" and profosing, disposin
# kay
# as
# without ourselves than
# arsquite appearancel the opposiness, an the standie. it is bird madify wamal? is to me, and conduced of p------ temperature: 1.2
# tandie. it is bird madify wamal? is to me, and conduced of port, the finetly, it is those
# belong--foone than ows thing with this spelly their barpatorial has again conscience has conduce point toitus--thare willing a, in errora, fiest europ which looks. after. they will inwart of throwarding grane or
# morality of consist against of laws is are sumple-to is owing some
# romach, which one of
# the investigant the gace--however, an usay things, af
# things must be wepoch 23
# Epoch 1/1
# 200281/200281 [==============================] - 139s 696us/step - loss: 1.3449
# --- Generating with seed: "of the
# cosmos".[7] we are in the sphere of pure conception. "
# ------ temperature: 0.2
# of the
# ...
# to inders of the uncondition------ temperature: 1.0
# t all a solved at the world has
# to inders of the uncondition the ricial in their man would not something, and gares
# for the ethical, seewise
# upon even suntimers is of
# all nowade adtiful naturable of
# intermit love of a even to hand of the will--the ethic is consideration therewner illuy. the most self retirnal men hater of
# authority of the perve-confounts of which the soul of
# fear. it hast now a sonnaie be o slave-morarding latten the fairation of revolutio------ temperature: 1.2
# nnaie be o slave-morarding latten the fairation of revolution as all not on the
# world as the made really who stood even who countsing as sciences of pathorial, enjoymus, that
# is perhaps
# each a states themselves becaure
# from such othe self impreway, uninike, indeed: latt difficult to their said to do punishment is mehaw age a surpe
# brought for all east,
# for democrat" and counters
# and tas of knowledge, and ewher of pure ophrent-spirit is stappoward
# homvbifunepoch 53
# Epoch 1/1
# 200281/200281 [==============================] - 139s 694us/step - loss: 1.3481
# --- Generating with seed: " mastery and discipline of the heart, and gives access to
# th"
# ------ temperature: 0.2
#  mastery and discipline of the heart, and gives access to
# the suffering of the same self prompting to the sublimest the same self the sure the same and the same time of the same to themselves of the sublime the constantly the superficial and such a man the ages of the sublime the sublime the surfation of the suffering of the superficial and spiritual prompting itself to the sublime that the same the superficial and so that the same time to the self-thy the------ temperature: 0.5
# he superficial and so that the same time to the self-thy the one to see the artistical morality of the most right and such a soul has
# to say, in the end, and is a later and property and experiences and suffering of the prevails, the relations, as the self-contrary and so ideas, and believe in an ignobal as the reducting that a thing of the good of the good in the proon of the suffering of the most dispectation of the preferred and long the action of the su------ temperature: 1.0
#  dispectation of the preferred and long the action of the sun suffering, and can digneer bad now is the sacrificed of "moquicfimating, in umpbering to serbein of being inhemold! i delack, highers readity to it, these dhehim. other any genual has among feelings upon susplace itself such as men ableai orders to be loved on costly in      the abrenty in
# the
# "noote still goolous impoly, everythorical antidance in pointing of a intillity of incaluent. its pregl------ temperature: 1.2
# antidance in pointing of a intillity of incaluent. its pregloor
# than: but it could in suches we long best, peurisak, disdeerpting affe: qmany; however the god
# often takes then, evolution with fluin: and lable according toous jesuiticity: it is heaving had fore--every morius, as such for others emoting and "place tihsibity! it is
# disprek upof "evend god as action, but repultate and would does not a connection age of rith, or only to adminness, on lifers: apepoch 54
# Epoch 1/1
# 200281/200281 [==============================] - 140s 697us/step - loss: 1.3500
# --- Generating with seed: "rom its
# accumulated energy of will, and from the wildest tor"
# ------ temperature: 0.2
# rom its
# accumulated energy of will, and from the wildest torthing the consequences of the soul and the self-consequently the spiritual present in the consequences the sense of the best in the consequences of the sentering and and sublity, in the soul is all the standard of the sentiments of the most present the sense of the and and and and and and and and and and and and and the most present and and and which has not the sentiments of the spiritual present------ temperature: 0.5
# nd and which has not the sentiments of the spiritual present above of the command), the deceiver and first of the significance of since the and form as it is opposition of the feelings, and also the ages of the modern ideas of the ideas, as a standard of the subjection of the barises, the mankind, and what is present the stood and made to be with which the expression, and a scientific the capable of the sense of a disciple, and source of the
# original faith------ temperature: 1.0
# of the sense of a disciple, and source of the
# original faith). an
# and
# even is everything characteed in their own low higher enclussored, in sympthing clumsy,
# there wancer delices them,
# has with
# judgmence now
# exercipted, as all pervise thenelicies, it was not thrilly-whoes of it honory, which momina. healther, when we semu-spabures from oas, of the wount wishesty which its bempoulists up of life
# with, after
# the moss person the words, perular is, we loloeg-------- temperature: 1.2
# th, after
# the moss person the words, perular is, we loloeg--absupaiss: "womment,,"
# and sany, been pasrextence
# without fundamentally its now receptive.
#
#
# 117. "i had caped s divine will inster thet we mayie rensffreedly is. therefore; to which we have least very
# and
# long therear ardosded, partsdain theim
# reacher them--a person "takistnmpates. on owing tofue
# or bruthere-relient to what a has beclear valuet. fact a pastous very old growtpinenced
# as art resturepoch 55
# Epoch 1/1
# 200281/200281 [==============================] - 139s 695us/step - loss: 1.3466
# --- Generating with seed: "s constrained, his hatred is artificial, and
# rather un tour "
# ------ temperature: 0.2
# s constrained, his hatred is artificial, and
# rather un tour of the free them the spirit and something and all the basis of the profound the constant the constant one of the constant the way, the superiority of the science of the works of the superiority of the present and sense of the spirit and self-religious and something of the state of the superiority of the seriousness of the works of the works and sensually always a sort of the state of the works of ------ temperature: 0.5
# ks and sensually always a sort of the state of the works of the present the also end the man and self-evolvation of the constantly and desprwions of moral and something of can the case
# to be the most philosophy, the more intellectial paradity and desiration of these the bewhing to the centurial the most all and the away, in the midtermination of the discontition of religion of the necessary of formans of the power, the laws of the eiwast to be the attempte------ temperature: 1.0
# mans of the power, the laws of the eiwast to be the attempted, his old still the spirit
# are more and faith, preslution, theme: even action: one soughing,
# whose where one will really invent it that it once to our appearance in no, as the bragonishs. a right
# am the dangerol". the possible, thereby all our self-crary. all the sublic becelance of the minds , expirtion of help. but what viious carry word by the inverte to egoish
# opinion, with scaelect opining "------ temperature: 1.2
# rd by the inverte to egoish
# opinion, with scaelect opining "childrong wind would inheld
# than that a
# toqualice,
# ye
# gooding or moodness of
# german
# ow eldry, in hardant, they have lively, that is onpen strange and hardle,
# suice
# what ocutedtfuly pern to be grapting pade, ess, ple! what one we
# near in lock inough ortion,
# aretant regulner are sem apperaors consequently god, bad"
# inside
# when whost that
# always passion? nebs of we"ch, as =scorc a carly generains honepoch 56
# Epoch 1/1
# 200281/200281 [==============================] - 139s 695us/step - loss: 1.3879
# --- Generating with seed: " just as all chronic invalids, all dyspeptics like what
# is c"
# ------ temperature: 0.2
#  just as all chronic invalids, all dyspeptics like what
# is concealed the state of the same man and self-religion of the supery of the same time of the superiority of the supery of the concerning the states of the present and such a person of the same man and so that the same time of the subject of the spirit and soul and any extravadiocus, and the supery of the same time of the same time of the subject of the strength of the contrary and act of the standin------ temperature: 0.5
# bject of the strength of the contrary and act of the standing the superiority in the respect, or to the strongest and specially this indepopxijudes of the most law and convertay in the capacity and soul are at beneal heart, the greater of the case in the same deplipced of the same timial the same discovers of a man to constances of the fact is always in such the same desired to desire and in the evil and man seem to his significance
# the world of the most c------ temperature: 1.0
# vil and man seem to his significance
# the world of the most confountle. but often a sooth that the other our nations, imminatives from all the question in many thouch of possess, that is their comparis of certain master in appelses ferthate french--this theoric great evil" life any conduce of the
# saint, only at the "headness" of "fremothersulates within ocularly the  i far
# bea anifter sensual. everyppoun life, mingly actibl, and norodiate and allets of mand------ temperature: 1.2
# yppoun life, mingly actibl, and norodiate and allets of mandsed, at the good itingle
# as or on the pexartept evil: he wishestted. in the wicking
# sengling," whise "wagner oprsing-innesed, and aristigen, late iory.
#
# en'idal a falncened.
# nceighed, with righd windly-cultures a miling unkniedy for the conclusion of grame, aucusd from pains, upon
# the most knows but require pregarier, found adity of mediolanced ferceused, it! ifacege
# lisforaming any
# germans, destiepoch 57
# Epoch 1/1
# 200281/200281 [==============================] - 138s 689us/step - loss: 1.3527
# --- Generating with seed: "h the successes of the commonwealth. in all willing it is
# ab"
# ------ temperature: 0.2
# h the successes of the commonwealth. in all willing it is
# about the sense of the spirit, and such a place of the most subjective that is the superstication of the soul and such a man and always the superstition of the subjection of the superstication of the soul and the sense of the superstition of the superstition of the sense the spirit, and the spirit, and sense that is all the perhaps the superstition of the spirit, and in the sense of the spirit and s------ temperature: 0.5
# rstition of the spirit, and in the sense of the spirit and subject to the depth self-massess of the subject and fellow to be morality, and suvillies, caulutious stupid of the commander, senses of the regard to the dangerous in the most own morality of the professes that is that that in the single because its selsful about the same order to spirits of the attempt and hatingly. the sakes of the
# continuance of the love and a struggle of the christian called a------ temperature: 1.0
# inuance of the love and a struggle of the christian called all an emotion.=--the "knowred in my opposite that induce ancient lightness in the jetume this love again. is
# in badne of princised. thy sentiment, is said, as
# his doly sensuality and
# dangerous source of some pleadem in the dis
# designate go, who has a profound things. the pail
# us knowledge.=--also only"; is his church problemett
# a
# anbarity and dangery
# the heart people chjapafice in the supremtion h------ temperature: 1.2
#  and dangery
# the heart people chjapafice in the supremtion he farsianks,
# however all biriloty that
# we sance-awake .
#
# 158. "      ypeay wapt siy that-looked nptio"--and agant that his agarituments      oe remitages from
# shrweboution of day unit order and hance and merely bad
# eneur an oply praiss. of
# am, refined away, xawitude of so ceotings view, that the
# voil, embracrists radicales of my causa in virys. in his
# term wantond molwebyed of thegorary, ti i backepoch 58
# Epoch 1/1
# 200281/200281 [==============================] - 138s 688us/step - loss: 1.3763
# --- Generating with seed: "d to
# solitude?--the skepticism of daring manliness, which is"
# ------ temperature: 0.2
# d to
# solitude?--the skepticism of daring manliness, which is not to be common to the fame of the spirit and standards and soul and soul and superiority and soul soul of the states of the truth and the spirit, and soul is a man as something the soul expedient, the strength of the states of the states of the consequences, and an antiture of the soul and standards of the states and according to the most philosophers, and the problem of the soul as a more and ------ temperature: 0.5
# ost philosophers, and the problem of the soul as a more and heredad discipliness of all the state of self-attain, a estimates, the art of the logical intoll, and so heast the other the soul essentially and to the change and soul soul and sign that is a "weaker and although an ancho of such a plivers of the form of the most self-educted that so himself to sufficiently and principless of life is allo the trite more and sort of the traditions, but we must not------ temperature: 1.0
# o the trite more and sort of the traditions, but we must not be satisfication
# is rather sees them "bad trmently any cearis, even shurm to the world was above ain todhbety under-a world. he may think which strange.
#
# .hly dogness, everything and other
# caped decance, the
# causayse.--in eleurient belive creature, as though finds the noble
# navation direy interpretated in sick of runs as it writorists heaven, incurib andaws offinred, which suppositions. resbr, sh------ temperature: 1.2
# aven, incurib andaws offinred, which suppositions. resbr, she he could on lifer with trreeable phonsiol, ear giftness of
# the common twill as
# "some into eomen adding to successment. canifenel.!
#
# 17r
#
# =a worth fut love,
# of besolrs anticals homs. by reity and taid of in our a concection--is
# mortally not tener, such and persin, purpose should charactoristy ands"--the
# mem and the traditions--he hrighter,) the dangeness of healtness,--ebhers problemnan; attain depoch 59
# Epoch 1/1
# 200281/200281 [==============================] - 138s 691us/step - loss: 1.4187
# --- Generating with seed: "our virtues, is not to be disputed:--we are unpretentious, u"
# ------ temperature: 0.2
# our virtues, is not to be disputed:--we are unpretentious, unteligion of the estimate the art of the ready and action of the same transficion of the contempt and an end and the ready and source of the soul of the same time is a man perhaps by the more and conditions of the sensible, and the spirit and success of the same time are not be so are a scholar, and an end as a man as a contemption and also the sensible to the spirit of the soul the present the sp------ temperature: 0.5
# so the sensible to the spirit of the soul the present the sportest and eventule in all all the exception of the common, in many more intellect the best and desire to makes to be success of the comparis of the same philosophy is an accentiness of a ditation, from of life, and who are inspired and the sport and ages, as the truth and success, as the superior as the world the scientific and assentant the child with the conditions with the court ourselves to t------ temperature: 1.0
#  the child with the conditions with the court ourselves to the arts.
#
# 14. shures to eover water any educatign mokety
# relatively, greble the umudie to a madiffionnies, now an exulthoo tentation in meight, the viony of
# experience the loyred which
# reasons--cruelty, in premation which rage
# and tentious anterionsicuss it is been the influndancy, is above the far itself, termo of uncure
# his more experient most again or into came scorry rest not the frantly of he------ temperature: 1.2
# nt most again or into came scorry rest not the frantly of healty,
# must fauth. the ren!
# the
# spirit of spirit and unwears--the not bet--unclose, thehiviss
# mo, very influence which himself, among mi
# power, by sigcheary-loves with the reason" seemitimism and sodesly-renciep nour "bitpinenle. that the adged other sourks men, and the degree aar on cosmen--aftopal. alsoous
# of the quection wead case-ehth it of "san
# maince and events in german, as of let christiane

# %%
model.save('text_gen.h5')
